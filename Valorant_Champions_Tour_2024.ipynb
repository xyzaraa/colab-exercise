# %% [markdown]
# ## Explanatory Data Analysis

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/VCT_2024.csv')

# %%
df.head(7)
# Out:
#   Region                              Event     Player Team Abbreviated  \
# 0   EMEA  Champions Tour 2024: EMEA Kickoff  AtaKaptan              FUT
# 1   EMEA  Champions Tour 2024: EMEA Kickoff    N4RRATE               KC
# 2   EMEA  Champions Tour 2024: EMEA Kickoff    MiniBoo               TH
# 3   EMEA  Champions Tour 2024: EMEA Kickoff  Chronicle              FNC
# 4   EMEA  Champions Tour 2024: EMEA Kickoff      Cloud               GX
# 5   EMEA  Champions Tour 2024: EMEA Kickoff     Zyppan             NAVI
# 6   EMEA  Champions Tour 2024: EMEA Kickoff    marteen               KC
#
#             Team  Rnd     R    ACS   K:D  KAST  ...   CL%    CL   CW    CP  \
# 0    FUT Esports  182  1.22  216.9  1.23  0.76  ...  0.17  4/23  4.0  23.0
# 1   Karmine Corp  383  1.21  249.9  1.27  0.78  ...  0.15  5/33  5.0  33.0
# 2  Team Heretics  208  1.19  254.7  1.22  0.69  ...  0.40  6/15  6.0  15.0
# 3         FNATIC   88  1.15  218.0  1.20  0.76  ...  0.42  5/12  5.0  12.0
# ...

# %%
df.tail(5)
# Out:
#     Region                               Event  Player Team Abbreviated  \
# 770  China  Champions Tour 2024: China Stage 2   nephh              BLG
# 771  China  Champions Tour 2024: China Stage 2   pl1xx              WOL
# 772  China  Champions Tour 2024: China Stage 2  Spring              WOL
# 773  China  Champions Tour 2024: China Stage 2   aluba              WOL
# 774  China  Champions Tour 2024: China Stage 2   B1ack              TEC
#
#                    Team  Rnd   R    ACS   K:D  KAST  ...  CL%   CL  CW  CP  \
# 770     Bilibili Gaming  370 NaN  202.5  0.97   NaN  ...  NaN  NaN NaN NaN
# 771      Wolves Esports  197 NaN  194.9  0.94   NaN  ...  NaN  NaN NaN NaN
# 772      Wolves Esports  197 NaN  233.7  1.01   NaN  ...  NaN  NaN NaN NaN
# 773      Wolves Esports  197 NaN  189.4  1.00   NaN  ...  NaN  NaN NaN NaN
# 774  Titan Esports Club  177 NaN  194.5  1.02   NaN  ...  NaN  NaN NaN NaN
#
#      KMax    K    D    A  FK  FD
# 770    23  259  266  170  33  26
# ...

# %%
df.isna().sum()
# Out:
# Region                0
# Event                 0
# Player                0
# Team Abbreviated      0
# Team                  0
# Rnd                   0
# R                   231
# ACS                   0
# K:D                   0
# KAST                231
# ADR                 113
# KPR                   0
# APR                   0
# FKPR                113
# FDPR                113
# HS%                 231
# CL%                 248
# CL                  231
# CW                  231
# CP                  231
# KMax                  0
# K                     0
# D                     0
# A                     0
# FK                    0
# FD                    0
# dtype: int64

# %%
df_clean = df.dropna()

# %%
df_clean.isna().sum()
# Out:
# Region              0
# Event               0
# Player              0
# Team Abbreviated    0
# Team                0
# Rnd                 0
# R                   0
# ACS                 0
# K:D                 0
# KAST                0
# ADR                 0
# KPR                 0
# APR                 0
# FKPR                0
# FDPR                0
# HS%                 0
# CL%                 0
# CL                  0
# CW                  0
# CP                  0
# KMax                0
# K                   0
# D                   0
# A                   0
# FK                  0
# FD                  0
# dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.histplot(df_clean['K:D'], bins=20)
plt.title('K:D Distribution')
plt.show()

# %%
top_players = df_clean.sort_values(by='HS%', ascending=False)
top_players.reset_index(drop=True, inplace=True)
top_players.head(4)
# Out:
#      Region                                  Event   Player Team Abbreviated  \
# 0   Pacific   Champions Tour 2024: Pacific Stage 2  primmie              TLN
# 1  Americas  Champions Tour 2024: Americas Stage 2  supamen               EG
# 2      EMEA      Champions Tour 2024: EMEA Stage 1    Elite              BBL
# 3   Pacific   Champions Tour 2024: Pacific Stage 1     Russ               GE
#
#              Team  Rnd     R    ACS   K:D  KAST  ...   CL%    CL   CW    CP  \
# 0   Talon Esports  118  1.02  254.5  1.06  0.69  ...  0.27  4/15  4.0  15.0
# 1   Evil Geniuses  242  1.04  214.6  1.08  0.73  ...  0.21  6/29  6.0  29.0
# 2     BBL Esports  268  1.16  214.2  1.31  0.75  ...  0.16  7/44  7.0  44.0
# 3  Global Esports  302  0.97  192.3  0.99  0.72  ...  0.24  7/29  7.0  29.0
#
#    KMax    K    D   A  FK  FD
# 0    28  107  101  24  19  15
# 1    23  192  177  65  22  37
# 2    23  215  164  45  18  17
# 3    21  210  212  95  25  27
#
# [4 rows x 26 columns]

# %%
top_players_subset = top_players[['Player', 'HS%']]
top_players_subset.head(4)
# Out:
#     Player   HS%
# 0  primmie  0.45
# 1  supamen  0.45
# 2    Elite  0.44
# 3     Russ  0.41

# %% [markdown]
# Here we have top 5 players by HS average: primmie, supamen, elite, russ, medusa

# %%
sns.displot(df_clean['HS%'])
plt.xlabel('Headshot Percentage')
plt.ylabel('Frekuensi')
plt.title("Head Shot")
plt.show()

# %%
sns.lineplot(df_clean['ACS'])
plt.title("Average Combat Score")
plt.show()

# %%
top_player_by_kill = df_clean.sort_values(by='K', ascending=False)
top_player_by_kill.reset_index(drop=True, inplace=True)
top_player_by_kill.head(10)
# Out:
#      Region                                  Event     Player  \
# 0   Pacific   Champions Tour 2024: Pacific Stage 1          t
# 1  Americas  Champions Tour 2024: Americas Stage 1      aspas
# 2      EMEA      Champions Tour 2024: EMEA Stage 1      Derke
# 3   Pacific   Champions Tour 2024: Pacific Stage 2       BuZz
# 4      EMEA      Champions Tour 2024: EMEA Stage 1    Alfajer
# 5      EMEA      Champions Tour 2024: EMEA Stage 1        Leo
# 6      EMEA      Champions Tour 2024: EMEA Stage 2       Sayf
# 7   Pacific   Champions Tour 2024: Pacific Stage 1     Meteor
# 8  Americas  Champions Tour 2024: Americas Stage 1       leaf
# 9      EMEA      Champions Tour 2024: EMEA Stage 1  Chronicle
#
#   Team Abbreviated           Team  Rnd     R    ACS   K:D  KAST  ...   CL%  \
# 0              GEN          Gen.G  627  1.12  235.3  1.20  0.72  ...  0.17
# 1              LEV       LEVIATÁN  544  1.25  260.3  1.51  0.75  ...  0.11
# ...

# %%
top_player_by_kill_inonemap = df_clean.sort_values(by='KMax', ascending=False)
top_player_by_kill_inonemap.reset_index(drop=True, inplace=True)
top_player_by_kill_inonemap.head(5)
# Out:
#      Region                                  Event      Player  \
# 0  Americas  Champions Tour 2024: Americas Stage 1       aspas
# 1      EMEA      Champions Tour 2024: EMEA Kickoff     N4RRATE
# 2      EMEA      Champions Tour 2024: EMEA Kickoff       Keiko
# 3   Pacific   Champions Tour 2024: Pacific Kickoff  Sayaplayer
# 4  Americas  Champions Tour 2024: Americas Stage 1         OXY
#
#   Team Abbreviated          Team  Rnd     R    ACS   K:D  KAST  ...   CL%  \
# 0              LEV      LEVIATÁN  544  1.25  260.3  1.51  0.75  ...  0.11
# 1               KC  Karmine Corp  383  1.21  249.9  1.27  0.78  ...  0.15
# 2               TL   Team Liquid  160  1.14  229.0  1.24  0.71  ...  0.05
# 3               T1            T1  163  1.10  215.1  1.29  0.74  ...  0.15
# 4               C9        Cloud9  383  1.22  291.1  1.26  0.75  ...  0.18
#
#      CL   CW    CP  KMax    K    D    A  FK  FD
# 0  8/73  8.0  73.0    47  519  344   91  89  58
# ...

# %%
sns.boxplot(x='Region', y='ACS', data=df_clean)
plt.title('Average Combat Score (ACS) by Region')
plt.xticks(rotation=45)
plt.show()

# %%
sns.boxplot(x='Region', y='KAST', data=df_clean)
plt.title('KAST by Region')
plt.xticks(rotation=45)
plt.show()

# %%
top_clutch_players = df_clean[['Player', 'CL%']].sort_values(by='CL%', ascending=False).head(10)
top_clutch_players
# Out:
#         Player   CL%
# 349       Shyy  0.54
# 68      nataNk  0.47
# 3    Chronicle  0.42
# 2      MiniBoo  0.40
# 357  Cryocells  0.40
# 123     nataNk  0.37
# 541    Haodong  0.36
# 207      Lakia  0.35
# 524     Autumn  0.33
# 531       Life  0.33

# %%
correlation_matrix = df_clean[['ACS', 'K:D', 'KAST', 'HS%']].corr()
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()
